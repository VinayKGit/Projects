# %%
#Import all Basic Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir("C:\\Users\\sowmy\\Downloads")

# %%
#import Data Set
Car_Dataset=pd.read_csv("car_prices.csv")

# %%
#perform Basic analysis on Data

# %%
Car_Dataset.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
Car_Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
Car_Dataset.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
Car_Dataset.shape
# Out:
# (558837, 16)

# %%
Car_Dataset.isna().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
#in this case i m dropping duplictes as assumption will cause more issues and may decrease accuracy.
Car_Dataset=Car_Dataset.dropna()

# %%
#Check Duplicates and drop if duplicates found
Car_Dataset.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns

# %%
#Carry out Basic Analysis on Data set

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=(20,7)
sns.countplot(x=Car_Dataset['year'],palette='cool')
plt.title("Average Car Price from 1990-2014")
plt.show()

# %%
#Top 20 cars by count
Make=Car_Dataset['make'].value_counts()
Make=Make.sort_values(ascending=False)[:20]
sns.barplot(x=Make,y=Make.index,palette='cool')
plt.title("Average Price ")
plt.show()

# %%
#Most Commonly available car colours
rcParams['figure.figsize']=(20,10)
sns.countplot(y=Car_Dataset['color'][:30],palette='dark',)
plt.show()

# %%
#Total Cars by Transmission Type
rcParams['figure.figsize']=(5,5)
plt.pie(Car_Dataset['transmission'].value_counts(),labels=Car_Dataset['transmission'].value_counts().index,autopct='%1.2f%%')
plt.show()

# %%
Interiors=Car_Dataset['interior'].value_counts()[:7]
Interiors.sort_values(ascending=False)
# Out:
# interior
# black    209865
# gray     152616
# beige     50469
# tan       37723
# —          9864
# brown      7102
# red        1128
# Name: count, dtype: int64

# %%
#Cars by Interiors Colour
plt.pie(Interiors,labels=Interiors.index,autopct='%1.0f%%')
Inner_Circle=plt.Circle((0,0),.7,fc='w')
plt.gca().add_artist(Inner_Circle)
plt.show()

# %%
#Cars by Interiors Trim
Trim=Car_Dataset['trim'].value_counts()

# %%
Trim=Trim.sort_values(ascending=False)[:10]

# %%
rcParams['figure.figsize']=(12,5)
sns.barplot(x=Trim,y=Trim.index)
plt.show()

# %%
#Average Price of Car by Year
Selling_Price_By_Year=Car_Dataset.groupby('year')['sellingprice'].mean()

# %%
sns.lineplot(x=Selling_Price_By_Year.index,y=Selling_Price_By_Year)
plt.grid(True,color='k')
plt.show()

# %%
#Average Price of car by Brand

# %%
Price_By_Brand=Car_Dataset.groupby('make')['sellingprice'].mean()

# %%
Price_By_Brand=Price_By_Brand.sort_values(ascending=False)

# %%
Price_By_Brand=Price_By_Brand[:20]

# %%
sns.barplot(x=Price_By_Brand,y=Price_By_Brand.index,palette='dark')
plt.show()

# %%
#Average Price by Model

# %%
sns.barplot(x=Price_By_Brand,y=Price_By_Brand.index,palette='dark')
# Out:
# <Axes: xlabel='sellingprice', ylabel='make'>

# %%
Price_By_model=Car_Dataset.groupby('model')['sellingprice'].mean()

# %%
Price_By_model=Price_By_model.sort_values(ascending=False)[:10]

# %%
sns.barplot(y=Price_By_model.index,x=Price_By_model,palette='deep')
# Out:
# <Axes: xlabel='sellingprice', ylabel='model'>

# %%
#Average Price of car by Body Type

# %%
Price_By_Body_Type=Car_Dataset.groupby('body')['sellingprice'].mean()

# %%
Price_By_Body_Type=Price_By_Body_Type.sort_values(ascending=False)[:20]

# %%
sns.barplot(y=Price_By_Body_Type.index,x=Price_By_Body_Type,palette='dark')
plt.show()

# %%
#Averagr Price by Transmission Type

# %%
Price_By_Transmission_Type=Car_Dataset.groupby('transmission')['sellingprice'].mean()

# %%
Price_By_Transmission_Type
# Out:
# transmission
# automatic    13774.510142
# manual       11349.721305
# Name: sellingprice, dtype: float64

# %%
rcParams['figure.figsize']=(6,3)
sns.barplot(x=Price_By_Transmission_Type.index,y=Price_By_Transmission_Type)
plt.show()

# %%
Price_By_Interiors=Car_Dataset.groupby('interior')['sellingprice'].mean()
Price_By_Interiors=Price_By_Interiors.sort_values()

# %%
sns.barplot(x=Price_By_Interiors,y=Price_By_Interiors.index)
# Out:
# <Axes: xlabel='sellingprice', ylabel='interior'>

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=(20,10)
import seaborn as sns
sns.boxplot(data=Car_Dataset,x='model',y='sellingprice',palette='deep')
plt.show()

# %%
#Check corelation between selling Price and Odometer reading and check for any outliers

# %%
plt.scatter(x=Car_Dataset['odometer'],y=Car_Dataset['sellingprice'])
plt.show()

# %%
plt.scatter(x=Car_Dataset['condition'],y=Car_Dataset['sellingprice'])
plt.show()

# %%
#Check Top dealers selling cars

# %%
Dealers=Car_Dataset['seller'].value_counts()

# %%
Dealers=Dealers.sort_values(ascending=False)[:15]

# %%
Dealers
# Out:
# seller
# ford motor credit company llc             17756
# the hertz corporation                     16286
# nissan-infiniti lt                        15777
# santander consumer                        14245
# avis corporation                          11471
# nissan infiniti lt                         9350
# wells fargo dealer services                7999
# tdaf remarketing                           6280
# ge fleet services for itself/servicer      5943
# enterprise veh exchange/rental             5727
# ahfc/honda lease trust/hvt  inc. eot       5576
# chrysler capital                           5340
# hyundai motor finance                      5256
# jpmorgan chase bank n.a.                   5091
# financial services remarketing (lease)     4948
# Name: count, dtype: int64

# %%
sns.barplot(x=Dealers,y=Dealers.index,palette='deep')
plt.show()

# %%
sns.pairplot(Car_Dataset)
# Out:
# C:\ProgramData\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(Car_Dataset['odometer'],bins=20)
plt.show()
# Out:
# C:\ProgramData\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Now since Basis Analysis on Data set is complete lets focus on building Model for Car Price Prediction

# %%
Car_Dataset.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
#Check Unique values of each column and replace if any errors found

# %%
Car_Dataset['year'].unique()
# Out:
# array([2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005,
#        2004, 2003, 2002, 2001, 2000, 1999, 1998, 1996, 1995, 1997, 1994,
#        1993, 1992, 1991, 1990], dtype=int64)

# %%
Car_Dataset['make'].unique()
# Out:
# array(['Kia', 'BMW', 'Volvo', 'Nissan', 'Chevrolet', 'Audi', 'Ford',
#        'Cadillac', 'Acura', 'Lexus', 'Hyundai', 'Buick', 'Infiniti',
#        'Jeep', 'Mercedes-Benz', 'Mitsubishi', 'Mazda', 'MINI',
#        'Land Rover', 'Lincoln', 'Jaguar', 'Volkswagen', 'Toyota',
#        'Subaru', 'Scion', 'Porsche', 'Dodge', 'FIAT', 'Chrysler',
#        'Ferrari', 'Honda', 'GMC', 'Ram', 'smart', 'Bentley', 'Pontiac',
#        'Saturn', 'Maserati', 'Mercury', 'HUMMER', 'Saab', 'Suzuki',
#        'Oldsmobile', 'Rolls-Royce', 'Isuzu', 'Plymouth', 'Tesla',
#        'Aston Martin', 'Geo', 'Fisker', 'Daewoo', 'Lamborghini', 'Lotus'],
#       dtype=object)

# %%
Car_Dataset['model'].unique()
# Out:
# array(['Sorento', '3 Series', 'S60', '6 Series Gran Coupe', 'Altima',
#        'M5', 'Cruze', 'A4', 'Camaro', 'A6', 'Optima', 'Fusion', 'Q5',
#        '6 Series', 'Impala', '5 Series', 'A3', 'XC70', 'SQ5', 'S5',
#        'Suburban', 'ELR', 'V60', 'X6', 'ILX', 'K900', 'Malibu', 'RX 350',
#        'Versa', 'Elantra', 'Versa Note', 'A8', 'X1', 'Enclave', 'TTS',
#        '4 Series', 'MDX', 'Silverado 1500', 'SRX', 'X5', 'G Coupe',
#        'G Sedan', 'FX', 'Santa Fe', 'Genesis', 'Equus', 'Sonata',
#        'Sonata Hybrid', 'Accent', 'Veloster', 'Elantra Coupe', 'Azera',
#        'Tucson', 'Genesis Coupe', 'Wrangler', 'S-Class', 'GS 350',
#        'Outlander', 'C-Class', 'Mazda2', 'Rio', 'M', '370Z', 'Soul',
#        'Outlander Sport', 'SLK-Class', 'ES 350', 'E-Class', 'Mazda3',
#        'Cooper Clubman', 'Cooper', 'CX-9', 'Forte', 'Compass', 'JX',
#        'LR4', 'Mazda5', 'Range Rover Evoque', 'LS 460', 'GLK-Class',
# ...

# %%
Car_Dataset['trim'].unique()
# Out:
# array(['LX', '328i SULEV', 'T5', ..., 'pure', 'EWB', 'Power Wagon'],
#       dtype=object)

# %%
Car_Dataset['state'].unique()
# Out:
# array(['ca', 'tx', 'mn', 'az', 'wi', 'tn', 'md', 'pa', 'fl', 'ne', 'oh',
#        'mi', 'nj', 'va', 'sc', 'in', 'il', 'co', 'ut', 'mo', 'ga', 'nv',
#        'ma', 'pr', 'nc', 'ny', 'or', 'la', 'wa', 'hi', 'ok', 'ms', 'nm',
#        'al'], dtype=object)

# %%
Car_Dataset['trim']=Car_Dataset['trim'].apply(lambda x:x.replace('  ...','TS'))

# %%
Car_Dataset['transmission'].unique()
# Out:
# array(['automatic', 'manual'], dtype=object)

# %%
Car_Dataset=Car_Dataset.drop(['vin','saledate'],axis=1)

# %%
Car_Dataset['condition'].unique()
# Out:
# array([ 5., 45., 41., 43.,  1., 34.,  2., 42.,  3., 48., 49., 17., 19.,
#        29., 38., 44., 47., 32.,  4., 25., 37., 39., 31., 28., 46., 35.,
#        26., 21., 36., 22., 27., 24., 33., 23., 16., 18., 12., 14., 11.,
#        13., 15.])

# %%
Car_Dataset['color'].unique()
# Out:
# array(['white', 'gray', 'black', 'red', 'silver', 'brown', 'beige',
#        'blue', 'purple', 'burgundy', '—', 'gold', 'yellow', 'green',
#        'charcoal', 'orange', 'off-white', 'turquoise', 'pink', 'lime'],
#       dtype=object)

# %%
Car_Dataset['color']=Car_Dataset['color'].apply(lambda x:x.replace('—','brown'))

# %%
Car_Dataset['interior'].unique()
# Out:
# array(['black', 'beige', 'tan', 'brown', '—', 'gray', 'burgundy', 'white',
#        'silver', 'off-white', 'red', 'yellow', 'green', 'purple', 'blue',
#        'orange', 'gold'], dtype=object)

# %%
Car_Dataset['interior']=Car_Dataset['interior'].apply(lambda x:x.replace('—','brown'))

# %%
Car_Dataset['interior'].unique()
# Out:
# array(['black', 'beige', 'tan', 'brown', 'gray', 'burgundy', 'white',
#        'silver', 'off-white', 'red', 'yellow', 'green', 'purple', 'blue',
#        'orange', 'gold'], dtype=object)

# %%
Car_Dataset['seller'].unique()
# Out:
# array(['kia motors america  inc',
#        'financial services remarketing (lease)',
#        'volvo na rep/world omni', ..., 'maserati north america inc',
#        'alternative financial group inc', 'i -5 uhlmann rv'], dtype=object)

# %%
Car_Dataset.head()
# Out:
#    year   make                model        trim   body transmission state  \
# 0  2015    Kia              Sorento          LX    SUV    automatic    ca
# 1  2015    Kia              Sorento          LX    SUV    automatic    ca
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic    ca
# 3  2015  Volvo                  S60          T5  Sedan    automatic    ca
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic    ca
#
#    condition  odometer  color interior  \
# 0        5.0   16639.0  white    black
# 1        5.0    9393.0  white    beige
# 2       45.0    1331.0   gray    black
# 3       41.0   14282.0  white    black
# 4       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice
# 0                 kia motors america  inc  20500.0       21500.0
# 1                 kia motors america  inc  20800.0       21500.0
# 2  financial services remarketing (lease)  31900.0       30000.0
# ...

# %%
#Get X and Y values

# %%
x=Car_Dataset.iloc[:,0:-1]

# %%
x
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558831  2011     BMW             5 Series         528i      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer  color interior  \
# 0         automatic    ca        5.0   16639.0  white    black
# ...

# %%
y=Car_Dataset.iloc[:,-1].values

# %%
y
# Out:
# array([21500., 21500., 30000., ..., 34000., 11100., 26700.])

# %%
x=pd.DataFrame(x)

# %%
#Apply Label encoder for categorial columns.One hoot encoding cannot be applied as there are too many unique values in each type and this may create issue .

# %%
x.iloc[:,1]=LE.fit_transform(x.iloc[:,1])

# %%
x.iloc[:,1]
# Out:
# 0         24
# 1         24
# 2          3
# 3         51
# 4          3
#           ..
# 558831     3
# 558833    41
# 558834     3
# 558835    36
# 558836    14
# Name: make, Length: 472325, dtype: object

# %%
x.iloc[:,2]=LE.fit_transform(x.iloc[:,2])

# %%
x.iloc[:,2]
# Out:
# 0         637
# 1         637
# 2           8
# 3         575
# 4          33
#          ...
# 558831     25
# 558833      6
# 558834    722
# 558835     63
# 558836    256
# Name: model, Length: 472325, dtype: object

# %%
x.iloc[:,3]=LE.fit_transform(x.iloc[:,3])

# %%
x.iloc[:,4]=LE.fit_transform(x.iloc[:,4])

# %%
x.iloc[:,5]=LE.fit_transform(x.iloc[:,5])

# %%
x.iloc[:,6]=LE.fit_transform(x.iloc[:,6])

# %%
x.iloc[:,9]=LE.fit_transform(x.iloc[:,9])

# %%
x.iloc[:,10]=LE.fit_transform(x.iloc[:,10])

# %%
x.iloc[:,11]=LE.fit_transform(x.iloc[:,11])

# %%
x.iloc[:,3]
# Out:
# 0          818
# 1          818
# 2          253
# 3         1212
# 4          335
#           ...
# 558831     316
# 558833     926
# 558834    1489
# 558835     102
# 558836    1394
# Name: trim, Length: 472325, dtype: object

# %%
x
# Out:
#         year make model  trim body transmission state  condition  odometer  \
# 0       2015   24   637   818   35            0     2        5.0   16639.0
# 1       2015   24   637   818   35            0     2        5.0    9393.0
# 2       2014    3     8   253   36            0     2       45.0    1331.0
# 3       2015   51   575  1212   36            0     2       41.0   14282.0
# 4       2014    3    33   335   36            0     2       43.0    2641.0
# ...      ...  ...   ...   ...  ...          ...   ...        ...       ...
# 558831  2011    3    25   316   36            0     4       39.0   66403.0
# 558833  2012   41     6   926   11            0    32        5.0   54393.0
# 558834  2012    3   722  1489   35            0     2       48.0   50561.0
# 558835  2015   36    63   102   76            0     5       38.0   16658.0
# 558836  2014   14   256  1394   38            0     2       34.0   15008.0
#
#        color interior seller      mmr
# ...

# %%
#Apply Minmax Scaler

# %%
from sklearn.preprocessing import minmax_scale

# %%
x_minmax=minmax_scale(x)

# %%
x_minmax
# Out:
# array([[1.        , 0.46153846, 0.83050847, ..., 0.06666667, 0.49849019,
#         0.11251546],
#        [1.        , 0.46153846, 0.83050847, ..., 0.        , 0.49849019,
#         0.11416403],
#        [0.96      , 0.05769231, 0.01043025, ..., 0.06666667, 0.34306324,
#         0.17516142],
#        ...,
#        [0.88      , 0.05769231, 0.94132986, ..., 0.06666667, 0.34306324,
#         0.16362138],
#        [1.        , 0.69230769, 0.0821382 , ..., 0.06666667, 0.31773192,
#         0.08284105],
#        [0.96      , 0.26923077, 0.33376793, ..., 0.4       , 0.36462003,
#         0.16252232]])

# %%
y
# Out:
# array([21500., 21500., 30000., ..., 34000., 11100., 26700.])

# %%
from sklearn.model_selection import train_test_split

# %%
X_Train,X_Test,Y_Train,Y_Test=train_test_split(x,y,test_size=.2)

# %%
X_Train.shape
# Out:
# (377860, 13)

# %%
X_Test.shape
# Out:
# (94465, 13)

# %%
#Build linear regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()

# %%
LR.fit(X_Train,Y_Train)
# Out:
# LinearRegression()

# %%
y_pred_lr=LR.predict(X_Test)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred_lr,Y_Test)
# Out:
# 0.9630287801078634

# %%
#Appply AdaBoost Regressor to check if Accuracy can be increased

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ADC=AdaBoostRegressor(estimator=LR,n_estimators=25,learning_rate=1)

# %%
ADC.fit(X_Train,Y_Train)
# Out:
# AdaBoostRegressor(estimator=LinearRegression(), learning_rate=1,
#                   n_estimators=25)

# %%
y_pred_ADC=ADC.predict(X_Test)

# %%
r2_score(y_pred_ADC,Y_Test)
# Out:
# 0.9680379976646512

# %%
#Apply cat Boost Model

# %%
from catboost import CatBoostRegressor

# %%
CBR=CatBoostRegressor()

# %%
CBR.fit(X_Train,Y_Train)
# Out:
# Learning rate set to 0.104568
# 0:	learn: 8694.4608944	total: 57.9ms	remaining: 57.8s
# 1:	learn: 7887.6733779	total: 106ms	remaining: 53.1s
# 2:	learn: 7169.8478356	total: 159ms	remaining: 52.7s
# 3:	learn: 6527.5155243	total: 210ms	remaining: 52.3s
# 4:	learn: 5963.3565382	total: 262ms	remaining: 52.1s
# 5:	learn: 5456.1201408	total: 310ms	remaining: 51.3s
# 6:	learn: 5002.8287525	total: 359ms	remaining: 50.9s
# 7:	learn: 4606.6632727	total: 412ms	remaining: 51.1s
# 8:	learn: 4259.8952334	total: 460ms	remaining: 50.6s
# 9:	learn: 3947.8604861	total: 504ms	remaining: 49.9s
# 10:	learn: 3675.9141829	total: 549ms	remaining: 49.4s
# 11:	learn: 3439.8634470	total: 596ms	remaining: 49.1s
# 12:	learn: 3230.9710360	total: 643ms	remaining: 48.8s
# 13:	learn: 3048.8161227	total: 693ms	remaining: 48.8s
# 14:	learn: 2893.2789191	total: 740ms	remaining: 48.6s
# 15:	learn: 2757.0151024	total: 789ms	remaining: 48.5s
# 16:	learn: 2642.9969221	total: 840ms	remaining: 48.5s
# ...

# %%
Y_Pred_CBR=CBR.predict(X_Test)

# %%
r2_score(Y_Pred_CBR,Y_Test)
# Out:
# 0.9728747972564987

# %%
#Apply cross validation to cross validate the consistency of prediction

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(CBR,X_Train,Y_Train,cv=5)
# Out:
# Learning rate set to 0.100945
# 0:	learn: 8704.1055434	total: 56.5ms	remaining: 56.5s
# 1:	learn: 7928.4802196	total: 97.4ms	remaining: 48.6s
# 2:	learn: 7235.8007251	total: 141ms	remaining: 46.7s
# 3:	learn: 6610.2642673	total: 181ms	remaining: 45s
# 4:	learn: 6049.7912864	total: 225ms	remaining: 44.8s
# 5:	learn: 5547.6242044	total: 267ms	remaining: 44.3s
# 6:	learn: 5106.9438265	total: 313ms	remaining: 44.5s
# 7:	learn: 4707.5574312	total: 355ms	remaining: 44s
# 8:	learn: 4356.8030332	total: 399ms	remaining: 44s
# 9:	learn: 4046.0080213	total: 459ms	remaining: 45.4s
# 10:	learn: 3771.7375342	total: 501ms	remaining: 45.1s
# 11:	learn: 3528.2124770	total: 543ms	remaining: 44.7s
# 12:	learn: 3313.9592023	total: 584ms	remaining: 44.4s
# 13:	learn: 3125.2331533	total: 625ms	remaining: 44s
# 14:	learn: 2966.1508719	total: 668ms	remaining: 43.9s
# 15:	learn: 2823.5007500	total: 706ms	remaining: 43.4s
# 16:	learn: 2700.8853759	total: 743ms	remaining: 42.9s
# ...

# %%
Y_Pred_CBR1_Final=CBR.predict(x)

# %%
Y_Pred_CBR1_Final
# Out:
# array([22801.72217835, 23139.30870573, 31392.75299001, ...,
#        30627.59673894, 16223.65459739, 28779.03273654])

# %%
r2_score(Y_Pred_CBR1_Final,y)
# Out:
# 0.9749037730225328

# %%
x
# Out:
#         year make model  trim body transmission state  condition  odometer  \
# 0       2015   24   637   818   35            0     2        5.0   16639.0
# 1       2015   24   637   818   35            0     2        5.0    9393.0
# 2       2014    3     8   253   36            0     2       45.0    1331.0
# 3       2015   51   575  1212   36            0     2       41.0   14282.0
# 4       2014    3    33   335   36            0     2       43.0    2641.0
# ...      ...  ...   ...   ...  ...          ...   ...        ...       ...
# 558831  2011    3    25   316   36            0     4       39.0   66403.0
# 558833  2012   41     6   926   11            0    32        5.0   54393.0
# 558834  2012    3   722  1489   35            0     2       48.0   50561.0
# 558835  2015   36    63   102   76            0     5       38.0   16658.0
# 558836  2014   14   256  1394   38            0     2       34.0   15008.0
#
#        color interior seller      mmr
# ...

# %%
Y_Pred_CBR1_Final.shape
# Out:
# (472325,)

# %%
x1=x.reset_index()

# %%
x1
# Out:
#          index  year    make                model         trim       body  \
# 0            0  2015     Kia              Sorento           LX        SUV
# 1            1  2015     Kia              Sorento           LX        SUV
# 2            2  2014     BMW             3 Series   328i SULEV      Sedan
# 3            3  2015   Volvo                  S60           T5      Sedan
# 4            4  2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...        ...   ...     ...                  ...          ...        ...
# 472320  558831  2011     BMW             5 Series         528i      Sedan
# 472321  558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  558834  2012     BMW                   X5    xDrive35d        SUV
# 472323  558835  2015  Nissan               Altima        2.5 S      sedan
# 472324  558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer  color interior  \
# ...

# %%
x1=pd.DataFrame(x1)

# %%
x1
# Out:
#          index  year    make                model         trim       body  \
# 0            0  2015     Kia              Sorento           LX        SUV
# 1            1  2015     Kia              Sorento           LX        SUV
# 2            2  2014     BMW             3 Series   328i SULEV      Sedan
# 3            3  2015   Volvo                  S60           T5      Sedan
# 4            4  2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...        ...   ...     ...                  ...          ...        ...
# 472320  558831  2011     BMW             5 Series         528i      Sedan
# 472321  558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  558834  2012     BMW                   X5    xDrive35d        SUV
# 472323  558835  2015  Nissan               Altima        2.5 S      sedan
# 472324  558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer  color interior  \
# ...

# %%
Y_Pred_CBR1_Final=pd.DataFrame(Y_Pred_CBR1_Final,columns=['Predicted'])

# %%
y=pd.DataFrame(y)

# %%
y
# Out:
#         level_0   index        0
# 0             0       0  21500.0
# 1             1       1  21500.0
# 2             2       2  30000.0
# 3             3       3  27750.0
# 4             4       4  67000.0
# ...         ...     ...      ...
# 472320   472320  472320  22800.0
# 472321   472321  472321  30800.0
# 472322   472322  472322  34000.0
# 472323   472323  472323  11100.0
# 472324   472324  472324  26700.0
#
# [472325 rows x 3 columns]

# %%
Final=pd.concat([x1,y,Y_Pred_CBR1_Final],axis=1)

# %%
Final
# Out:
#          index  year    make                model         trim       body  \
# 0            0  2015     Kia              Sorento           LX        SUV
# 1            1  2015     Kia              Sorento           LX        SUV
# 2            2  2014     BMW             3 Series   328i SULEV      Sedan
# 3            3  2015   Volvo                  S60           T5      Sedan
# 4            4  2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...        ...   ...     ...                  ...          ...        ...
# 472320  558831  2011     BMW             5 Series         528i      Sedan
# 472321  558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  558834  2012     BMW                   X5    xDrive35d        SUV
# 472323  558835  2015  Nissan               Altima        2.5 S      sedan
# 472324  558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer  color interior  \
# ...

# %%
Final=Final.drop(['index','condition','odometer','level_0','index'],axis=1)

# %%
Final=Final.drop(['mmr'],axis=1)

# %%
Final
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 472320  2011     BMW             5 Series         528i      Sedan
# 472321  2012     Ram                 2500  Power Wagon   Crew Cab
# 472322  2012     BMW                   X5    xDrive35d        SUV
# 472323  2015  Nissan               Altima        2.5 S      sedan
# 472324  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  color interior  \
# 0         automatic    ca  white    black
# 1         automatic    ca  white    beige
# 2         automatic    ca   gray    black
# ...

# %%
plt.plot(Final[0])
plt.plot(Final['Predicted'])
plt.show()
