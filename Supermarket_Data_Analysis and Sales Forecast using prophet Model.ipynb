# %%
#Import Necssary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import seaborn as sns
plt.rcParams['figure.figsize'] = (5,3)
import os

# %%
os.chdir("C:\\Users\\sowmy\\Downloads")

# %%
#Import Data Set
Sales_DS=pd.read_excel("Supermarket_sales.xlsx")

# %% [markdown]
# #Carry out Basic checks on Data sets

# %%
Sales_DS.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date  Delivery Duration  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11                  3
# 1       2  CA-2016-152156 2016-11-08 2016-11-11                  3
# 2       3  CA-2016-138688 2016-06-12 2016-06-16                  4
# 3       4  US-2015-108966 2015-10-11 2015-10-18                  7
# 4       5  US-2015-108966 2015-10-11 2015-10-18                  7
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#         Product ID         Category  Sub-Category  \
# ...

# %%
Sales_DS.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Delivery Duration',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Discount Value', 'Profit', 'COGS'],
#       dtype='object')

# %%
Sales_DS.isna().sum()
# Out:
# Row ID               0
# Order ID             0
# Order Date           0
# Ship Date            0
# Delivery Duration    0
# Ship Mode            0
# Customer ID          0
# Customer Name        0
# Segment              0
# Country              0
# City                 0
# State                0
# Postal Code          0
# Region               0
# Product ID           0
# Category             0
# Sub-Category         0
# Product Name         0
# Sales                0
# Quantity             0
# Discount             0
# Discount Value       0
# Profit               0
# COGS                 0
# dtype: int64

# %%
Sales_DS.duplicated().sum()
# Out:
# 0

# %%
Sales_DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Row ID             9994 non-null   int64
#  1   Order ID           9994 non-null   object
#  2   Order Date         9994 non-null   datetime64[ns]
#  3   Ship Date          9994 non-null   datetime64[ns]
#  4   Delivery Duration  9994 non-null   int64
#  5   Ship Mode          9994 non-null   object
#  6   Customer ID        9994 non-null   object
#  7   Customer Name      9994 non-null   object
#  8   Segment            9994 non-null   object
#  9   Country            9994 non-null   object
#  10  City               9994 non-null   object
#  11  State              9994 non-null   object
#  12  Postal Code        9994 non-null   int64
#  13  Region             9994 non-null   object
#  14  Product ID         9994 non-null   object
# ...

# %%
Sales_DS['Month']=Sales_DS['Order Date'].dt.month

# %%
Sales_DS['Year']=Sales_DS['Order Date'].dt.year

# %%
Sales_DS['Quarte']=Sales_DS['Order Date'].dt.quarter

# %%
Sales_DS
# Out:
#       Row ID        Order ID Order Date  Ship Date  Delivery Duration  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11                  3
# 1          2  CA-2016-152156 2016-11-08 2016-11-11                  3
# 2          3  CA-2016-138688 2016-06-12 2016-06-16                  4
# 3          4  US-2015-108966 2015-10-11 2015-10-18                  7
# 4          5  US-2015-108966 2015-10-11 2015-10-18                  7
# ...      ...             ...        ...        ...                ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23                  2
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03                  5
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03                  5
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03                  5
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09                  5
#
#            Ship Mode Customer ID     Customer Name    Segment        Country  \
# ...

# %% [markdown]
# #Carry out Data Analysis and Trends on Data Set

# %%
Yearly_Sales_Trend=Sales_DS.groupby('Year')['Sales'].mean()

# %%
#Yearly Sales Trend
rcParams['figure.figsize']=(12,6)
sns.lineplot(x=Yearly_Sales_Trend.index,y=Yearly_Sales_Trend,palette='deep')
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Yearly Sales Trend")
plt.grid('k')
plt.show()
# Out:
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_6788\1006184190.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=Yearly_Sales_Trend.index,y=Yearly_Sales_Trend,palette='deep')

# %%
#Monthly Sales Trend
Monthly_Sales_Trend=Sales_DS.groupby('Month')['Sales'].mean()

# %%
Monthly_Sales_Trend
# Out:
# Month
# 1     249.146550
# 2     199.170838
# 3     294.548116
# 4     206.230731
# 5     210.923553
# 6     212.996763
# 7     207.377601
# 8     225.274877
# 9     222.451154
# 10    244.594609
# 11    239.606438
# 12    231.032318
# Name: Sales, dtype: float64

# %%
rcParams['figure.figsize']=(12,6)
sns.lineplot(x=Monthly_Sales_Trend.index,y=Monthly_Sales_Trend,palette='deep')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("Monthly Sales Trend")
plt.grid('k')
plt.show()
# Out:
# C:\Users\sowmy\AppData\Local\Temp\ipykernel_6788\2095297611.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=Monthly_Sales_Trend.index,y=Monthly_Sales_Trend,palette='deep')

# %%
#Quantity Shipped by different Means
Ship_Mode=Sales_DS.groupby('Ship Mode')['Quantity'].mean()

# %%
sns.barplot(x=Ship_Mode.index,y=Ship_Mode)
plt.xlabel("Ship Mode")
plt.ylabel("Quantity")
plt.show()

# %%
#Sales from Distinct Segment
Sales_By_Segment=Sales_DS.groupby('Segment')['Sales'].mean()

# %%
rcParams['figure.figsize']=(5,5)
plt.pie(Sales_By_Segment,labels=Sales_By_Segment.index,autopct='%1.1f%%',explode=(.1,.1,.1))
plt.title("Sales By Distinct Segment")
plt.legend('left')
plt.show()

# %%
#Profit from distinct segment
Profit_By_Segment=Sales_DS.groupby('Segment')['Profit'].mean()

# %%
rcParams['figure.figsize']=(5,5)
plt.pie(Profit_By_Segment,labels=Profit_By_Segment.index,autopct='%1.1f%%',explode=(.1,.1,.1))
plt.title("Profit By Distinct Segment")
plt.legend('left')
plt.show()

# %%
Sales_By_Country=Sales_DS.groupby('Country')['Sales'].mean()

# %%
Sales_By_Country
# Out:
# Country
# United States    229.858001
# Name: Sales, dtype: float64

# %%
#Sales from distinct city in US
Sales_By_City=Sales_DS.groupby('City')['Sales'].mean()

# %%
Sales_By_City=Sales_By_City.sort_values(ascending=False)[:10]

# %%
Sales_By_City
# Out:
# City
# Jamestown       2354.395000
# Cheyenne        1603.136000
# Bellingham      1263.413333
# Independence    1208.685000
# Burbank         1082.386000
# Buffalo          906.349600
# Burlington       866.723280
# Beverly          861.063333
# Sparks           853.986667
# Appleton         835.655000
# Name: Sales, dtype: float64

# %%
rcParams['figure.figsize']=(15,3)
sns.barplot(x=Sales_By_City.index,y=Sales_By_City)
plt.title("Top 10 US Cities Generating Highest Sales")
plt.show()

# %%
#Proffit from Distinct Cities in US
Profit_By_City=Sales_DS.groupby('City')['Profit'].mean()

# %%
Profit_By_City
# Out:
# City
# Aberdeen         6.630000
# Abilene         -3.758400
# Akron           -8.887410
# Albuquerque     45.292007
# Alexandria      19.913644
#                   ...
# Woonsocket      19.669775
# Yonkers        184.517047
# York           -20.433840
# Yucaipa         13.208000
# Yuma          -116.497725
# Name: Profit, Length: 531, dtype: float64

# %%
Profit_By_City=Profit_By_City.sort_values(ascending=False)[:10]

# %%
rcParams['figure.figsize']=(15,3)
sns.barplot(x=Profit_By_City.index,y=Profit_By_City)
plt.title("Top 10 US Cities Generating Highest Profit")
plt.show()

# %%
sns.scatterplot(x=Sales_DS['Discount'],y=Sales_DS['Sales'])
plt.show()

# %%
Sales_DS.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Delivery Duration',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Discount Value', 'Profit', 'COGS', 'Month', 'Year', 'Quarte'],
#       dtype='object')

# %%
Sales_By_Category=Sales_DS.groupby('Category')['Sales'].mean()

# %%
Sales_By_Category
# Out:
# Category
# Furniture          349.834887
# Office Supplies    119.324101
# Technology         452.709276
# Name: Sales, dtype: float64

# %%
rcParams['figure.figsize']=(7,3)
sns.barplot(x=Sales_By_Category,y=Sales_By_Category.index)
plt.title("Sales by Category")
plt.show()

# %%
#Sales by category
Sales_By_SubCategory=Sales_DS.groupby('Sub-Category')['Sales'].mean()

# %%
Sales_By_SubCategory
# Out:
# Sub-Category
# Accessories     215.974604
# Appliances      230.755710
# Art              34.068834
# Binders         133.560560
# Bookcases       503.859633
# Chairs          532.332420
# Copiers        2198.941618
# Envelopes        64.867724
# Fasteners        13.936774
# Furnishings      95.825668
# Labels           34.303055
# Machines       1645.553313
# Paper            57.284092
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Tables          648.794771
# Name: Sales, dtype: float64

# %%
#Sales by sub category
Sales_By_SubCategory=Sales_By_SubCategory.sort_values(ascending=False)

# %%
rcParams['figure.figsize']=(7,3)
sns.barplot(x=Sales_By_SubCategory,y=Sales_By_SubCategory.index,palette='dark')
plt.title("Sales by Sub Category")
plt.show()

# %%
Sales_By_Product=Sales_DS.groupby('Product Name')['Sales'].mean()

# %%
Sales_By_Product=Sales_By_Product.sort_values(ascending=False)

# %%
Sales_By_Product
# Out:
# Product Name
# Cisco TelePresence System EX90 Videoconferencing Unit                         22638.4800
# Canon imageCLASS 2200 Advanced Copier                                         12319.9648
# Cubify CubeX 3D Printer Triple Head Print                                      7999.9800
# 3D Systems Cube Printer, 2nd Generation, Magenta                               7149.9450
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      6124.9650
#                                                                                  ...
# Acco Economy Flexible Poly Round Ring Binder                                      2.8710
# Computer Printout Index Tabs                                                      2.7720
# Hoover Replacement Belt for Commercial Guardsman Heavy-Duty Upright Vacuum        2.4420
# Maxell 4.7GB DVD+R 5/Pack                                                         2.3364
# ...

# %%
Top_10_Products=Sales_By_Product.sort_values(ascending=False)[:10]

# %%
rcParams['figure.figsize']=(7,3)
sns.barplot(x=Top_10_Products,y=Top_10_Products.index,palette='dark')
plt.title("Top 10 Product By Average Sales")
plt.show()

# %%
#Sales by region
Sales_By_Region=Sales_DS.groupby('Region')['Sales'].mean()

# %%
rcParams['figure.figsize']=(15,5)
plt.pie(Sales_By_Region,labels=Sales_By_Region.index,autopct="%1.2f%%")
Inner_circle=plt.Circle((0,0),.7,fc='w')
plt.gca().add_artist(Inner_circle)
plt.title("Sales By Region")
plt.show()

# %%
#Check for outliers in Data

# %%
sns.boxenplot(x=Sales_DS['Category'],y=Sales_DS['Sales'])
plt.show()

# %%
sns.boxplot(x=Sales_DS['Region'],y=Sales_DS['Sales'])
plt.show()

# %%
sns.boxenplot(x=Sales_DS['Segment'],y=Sales_DS['Sales'])
plt.show()

# %% [markdown]
# #Prepare Data to be used for Building Machine learning Model.Remove all unnecessarycolumns and Label Encode

# %%
Sales_DS.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Delivery Duration',
#        'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country',
#        'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Discount Value', 'Profit', 'COGS', 'Month', 'Year', 'Quarte'],
#       dtype='object')

# %%
Sales_DS=Sales_DS.drop(['Row ID','Order ID','Customer ID','Customer Name','Postal Code','Product ID'],axis=1)

# %%
Sales_DS
# Out:
#      Order Date  Ship Date  Delivery Duration       Ship Mode    Segment  \
# 0    2016-11-08 2016-11-11                  3    Second Class   Consumer
# 1    2016-11-08 2016-11-11                  3    Second Class   Consumer
# 2    2016-06-12 2016-06-16                  4    Second Class  Corporate
# 3    2015-10-11 2015-10-18                  7  Standard Class   Consumer
# 4    2015-10-11 2015-10-18                  7  Standard Class   Consumer
# ...         ...        ...                ...             ...        ...
# 9989 2014-01-21 2014-01-23                  2    Second Class   Consumer
# 9990 2017-02-26 2017-03-03                  5  Standard Class   Consumer
# 9991 2017-02-26 2017-03-03                  5  Standard Class   Consumer
# 9992 2017-02-26 2017-03-03                  5  Standard Class   Consumer
# 9993 2017-05-04 2017-05-09                  5    Second Class   Consumer
#
#             Country             City       State Region         Category  ...  \
# ...

# %%
Sales_DS.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Delivery Duration', 'Ship Mode', 'Segment',
#        'Country', 'City', 'State', 'Region', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Discount Value',
#        'Profit', 'COGS', 'Month', 'Year', 'Quarte'],
#       dtype='object')

# %%
Sales_Project=Sales_DS[['Order Date','Segment','Country', 'City', 'State', 'Region', 'Category', 'Sub-Category',
       'Product Name', 'Sales']]

# %%
Sales_Project=Sales_Project.sort_values(by='Order Date')

# %%
Sales_Project
# Out:
#      Order Date      Segment        Country           City         State  \
# 7980 2014-01-03     Consumer  United States        Houston         Texas
# 739  2014-01-04  Home Office  United States     Naperville      Illinois
# 740  2014-01-04  Home Office  United States     Naperville      Illinois
# 741  2014-01-04  Home Office  United States     Naperville      Illinois
# 1759 2014-01-05     Consumer  United States   Philadelphia  Pennsylvania
# ...         ...          ...            ...            ...           ...
# 5091 2017-12-30     Consumer  United States       Loveland      Colorado
# 908  2017-12-30     Consumer  United States  New York City      New York
# 907  2017-12-30     Consumer  United States  New York City      New York
# 1296 2017-12-30    Corporate  United States      Fairfield    California
# 906  2017-12-30     Consumer  United States  New York City      New York
#
#        Region         Category Sub-Category  \
# 7980  Central  Office Supplies        Paper
# ...

# %%
Sales_Project['Month']=Sales_Project['Order Date'].dt.month

# %%
Sales_Project['Year']=Sales_Project['Order Date'].dt.year

# %%
Sales_Project=Sales_Project.rename(columns={'Order Date':'ds','Sales':'y'})

# %%
Sales_Project
# Out:
#              ds      Segment        Country           City         State  \
# 7980 2014-01-03     Consumer  United States        Houston         Texas
# 739  2014-01-04  Home Office  United States     Naperville      Illinois
# 740  2014-01-04  Home Office  United States     Naperville      Illinois
# 741  2014-01-04  Home Office  United States     Naperville      Illinois
# 1759 2014-01-05     Consumer  United States   Philadelphia  Pennsylvania
# ...         ...          ...            ...            ...           ...
# 5091 2017-12-30     Consumer  United States       Loveland      Colorado
# 908  2017-12-30     Consumer  United States  New York City      New York
# 907  2017-12-30     Consumer  United States  New York City      New York
# 1296 2017-12-30    Corporate  United States      Fairfield    California
# 906  2017-12-30     Consumer  United States  New York City      New York
#
#        Region         Category Sub-Category  \
# 7980  Central  Office Supplies        Paper
# ...

# %% [markdown]
# #Forecast sales using prophet Model for next 2 Years

# %%
from prophet import Prophet
from prophet.plot import plot_components,plot_plotly

# %%
model=Prophet()

# %%
model.fit(Sales_Project)
# Out:
# 01:30:04 - cmdstanpy - INFO - Chain [1] start processing
# 01:30:05 - cmdstanpy - INFO - Chain [1] done processing

# %%
Forecasting=model.make_future_dataframe(periods=730)

# %%
predictions=model.predict(Forecasting)

# %%
predictions[['ds','trend','yhat']]
# Out:
#              ds       trend        yhat
# 0    2014-01-03  233.479700  236.009176
# 1    2014-01-04  233.498387  216.251787
# 2    2014-01-05  233.517075  222.771877
# 3    2014-01-06  233.535762  223.506750
# 4    2014-01-07  233.554450  251.591797
# ...         ...         ...         ...
# 1962 2019-12-26  178.585950  188.125767
# 1963 2019-12-27  178.535119  199.588821
# 1964 2019-12-28  178.484288  180.150570
# 1965 2019-12-29  178.433457  186.429065
# 1966 2019-12-30  178.382626  186.344747
#
# [1967 rows x 3 columns]

# %%
plot_plotly(model,predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_plotly(model,predictions)
#
# NameError: name 'plot_plotly' is not defined

# %%
Forecasting=predictions[['ds','trend','yhat']]

# %%
Forecasting.plot(x='ds',y=['trend','yhat'])
plt.show()
